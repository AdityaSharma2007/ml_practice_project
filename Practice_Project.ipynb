# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaSharma2007/ml_practice_project/blob/main/Practice_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd


df = pd.read_csv('/content/placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df = df.iloc[:,1:]
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]
print(x)
print(y)
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
y_train
x_test
# Out:
#     cgpa     iq
# 61   7.3  137.0
# 80   4.9  196.0
# 86   5.1  128.0
# 92   5.2  110.0
# 76   4.9  155.0
# 56   6.1   65.0
# 20   6.6  120.0
# 11   6.9  138.0
# 35   6.8   90.0
# 98   6.3  103.0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_test
x_train
# Out:
# array([[-0.50577677, -0.4097465 ],
#        [ 0.26720282,  0.0865817 ],
#        [-0.16223028,  0.45882784],
#        [ 0.1813162 , -0.26084804],
#        [-1.0210965 ,  0.97997244],
#        [-1.45052961,  1.8981796 ],
#        [ 1.81316201,  0.63254271],
#        [-1.10698312, -1.77464902],
#        [-0.93520988,  0.26029656],
#        [-0.59166339, -0.23603163],
#        [-1.10698312, -0.90607469],
#        [-0.16223028,  1.05442167],
#        [-2.30939582,  1.47630063],
#        [ 0.00954296,  0.01213247],
#        [ 0.86840917, -0.28566445],
#        [ 0.09542958,  0.21066374],
#        [-0.84932326, -0.13676599],
#        [ 0.43897606,  0.16103092],
#        [ 1.3837289 ,  0.11139811],
#        [ 1.81316201,  1.05442167],
#        [-0.24811691,  0.40919502],
#        [ 1.29784228,  0.16103092],
#        [ 0.43897606, -2.14689517],
#        [ 0.00954296, -1.42721929],
#        [ 0.69663593,  0.43401143],
#        [-0.93520988, -1.55130134],
#        [-1.36464298,  0.63254271],
#        [ 0.95429579,  0.68217553],
#        [-1.70818947, -1.2038716 ],
#        [-0.50577677,  0.28511297],
#        [ 0.43897606,  0.90552321],
#        [ 1.98493525,  1.10405449],
#        [ 0.86840917,  1.27776936],
#        [-0.76343663,  1.30258577],
#        [ 1.12606904, -1.82428184],
#        [ 0.78252255,  0.38437861],
#        [ 0.52486269,  0.3595622 ],
#        [-0.24811691,  0.21066374],
#        [-0.24811691,  0.48364425],
#        [ 0.61074931,  0.75662475],
#        [ 0.26720282,  0.11139811],
#        [-1.19286974,  0.55809348],
#        [ 0.43897606, -0.83162546],
#        [-0.76343663, -1.42721929],
#        [ 0.35308944, -0.18639881],
#        [-0.67755001,  2.49377343],
#        [ 0.00954296, -0.53382854],
#        [ 1.12606904, -0.18639881],
#        [ 0.86840917,  0.38437861],
#        [ 0.69663593, -0.01268394],
#        [-0.07634366, -0.43456291],
#        [ 0.00954296,  0.63254271],
#        [-1.79407609, -0.36011368],
#        [-0.84932326, -1.50166852],
#        [ 0.09542958,  0.80625757],
#        [ 0.78252255, -0.682727  ],
#        [-0.67755001, -0.83162546],
#        [-0.24811691,  1.1288709 ],
#        [ 0.69663593, -0.28566445],
#        [-0.93520988,  0.68217553],
#        [ 1.12606904, -0.9308911 ],
#        [-1.0210965 ,  0.43401143],
#        [ 1.29784228,  0.85589039],
#        [-1.10698312, -0.06231676],
#        [ 1.29784228, -1.55130134],
#        [ 0.09542958, -1.05497315],
#        [ 0.09542958, -0.50901213],
#        [ 1.3837289 , -0.85644187],
#        [ 0.95429579, -1.87391466],
#        [ 0.61074931,  1.45148422],
#        [ 1.21195566,  0.21066374],
#        [ 0.00954296, -1.94836389],
#        [-1.0210965 ,  1.1288709 ],
#        [-0.67755001,  0.21066374],
#        [-0.67755001,  0.93033962],
#        [-0.50577677,  0.38437861],
#        [-2.13762258,  2.71712111],
#        [-0.93520988, -0.08713317],
#        [ 0.86840917, -1.47685211],
#        [-1.36464298, -2.02281312],
#        [-1.70818947, -0.58346136],
#        [ 0.35308944,  0.43401143],
#        [ 0.86840917,  1.87336319],
#        [-0.84932326, -0.80680905],
#        [-1.0210965 , -0.28566445],
#        [-0.59166339, -0.06231676],
#        [ 2.15670849, -0.08713317],
#        [ 1.72727539, -1.10460596],
#        [ 1.55550214, -0.23603163],
#        [-0.50577677, -0.23603163]])

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x_train, y_train.values,model, legend=2)
# Out:
# <Axes: >

# %%
import pickle
pickle.dump(model,open('model.pkl','wb'))
